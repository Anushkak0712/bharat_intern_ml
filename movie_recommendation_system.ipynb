# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushkak0712/bharat_intern_ml/blob/main/movie_recommendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd




# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
tag=pd.read_csv('/content/tag.csv')
rating=pd.read_csv('/content/rating.csv')
movies=pd.read_csv('/content/movie.csv')
genome_scores=pd.read_csv('/content/genome_scores.csv')
link=pd.read_csv('/content/link.csv')
genome_tag=pd.read_csv('/content/genome_tags.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
link.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
rating.shape
# Out:
# (351018, 4)

# %%
rating['userId'].value_counts().shape ## unique users
# Out:
# (2368,)

# %%
x=rating['userId'].value_counts()>500

# %%
y = x[x].index

# %%
y.shape
# Out:
# (140,)

# %%
rating=rating[rating['userId'].isin(y)]

# %%
rating.shape
# Out:
# (115871, 4)

# %%
movie_details=movies.merge(rating,on='movieId')

# %%
movie_details.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating            timestamp
# 0      11     4.5  2009-01-02 01:13:41
# 1      24     4.0  2001-07-04 07:02:29
# 2      54     4.0  2000-11-21 21:00:21
# 3      58     5.0  2006-04-03 10:00:08
# 4      91     4.0  2005-03-22 22:46:02

# %%
movie_details.shape
# Out:
# (115871, 6)

# %%
movie_details.drop(columns=['timestamp'],inplace=True)

# %%
movie_details.shape
# Out:
# (115871, 5)

# %%
movie_details.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating
# 0      11     4.5
# 1      24     4.0
# 2      54     4.0
# 3      58     5.0
# 4      91     4.0

# %%
number_rating = movie_details.groupby('title')['rating'].count().reset_index()

# %%
number_rating.rename(columns={'rating':'number of rating'},inplace=True)

# %%
number_rating.head()
# Out:
#                        title  number of rating
# 0     'Round Midnight (1986)                 1
# 1        'Salem's Lot (2004)                 2
# 2  'Til There Was You (1997)                 5
# 3         'burbs, The (1989)                26
# 4       'night Mother (1986)                 2

# %%
df=movie_details.merge(number_rating,on='title')

# %%
df.shape
# Out:
# (115871, 6)

# %%
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating  number of rating
# 0      11     4.5               116
# 1      24     4.0               116
# 2      54     4.0               116
# 3      58     5.0               116
# 4      91     4.0               116

# %%
df=df[df['number of rating']>=50] #selecting valuable books by ratings

# %%
df.drop_duplicates(['title','userId'],inplace=True)

# %%
df.shape
# Out:
# (38950, 6)

# %%
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating  number of rating
# 0      11     4.5               116
# 1      24     4.0               116
# 2      54     4.0               116
# 3      58     5.0               116
# 4      91     4.0               116

# %%
df.drop(columns=['number of rating'],inplace=True)

# %%
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating
# 0      11     4.5
# 1      24     4.0
# 2      54     4.0
# 3      58     5.0
# 4      91     4.0

# %%
df['rating']=df['rating'].astype(int)

# %%
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating
# 0      11       4
# 1      24       4
# 2      54       4
# 3      58       5
# 4      91       4

# %%
movie_pivot=df.pivot_table(columns='userId',index='title',values='rating')

# %%
movie_pivot.shape
# Out:
# (526, 140)

# %%
movie_pivot.fillna(0,inplace=True)

# %%
movie_pivot
# Out:
# userId                                              11    24    54    58    \
# title
# 101 Dalmatians (One Hundred and One Dalmatians)...   0.0   0.0   0.0   0.0
# 2001: A Space Odyssey (1968)                         0.0   0.0   2.0   5.0
# 28 Days Later (2002)                                 5.0   0.0   0.0   4.0
# 40-Year-Old Virgin, The (2005)                       5.0   0.0   0.0   0.0
# A.I. Artificial Intelligence (2001)                  5.0   0.0   0.0   3.0
# ...                                                  ...   ...   ...   ...
# X-Men (2000)                                         5.0   3.0   4.0   3.0
# X2: X-Men United (2003)                              5.0   0.0   0.0   0.0
# You've Got Mail (1998)                               0.0   0.0   3.0   0.0
# Young Frankenstein (1974)                            0.0   0.0   4.0   5.0
# Zoolander (2001)                                     0.0   0.0   0.0   0.0
#
# userId                                              91    104   116   134   \
# title
# 101 Dalmatians (One Hundred and One Dalmatians)...   0.0   3.0   0.0   0.0
# 2001: A Space Odyssey (1968)                         2.0   4.0   0.0   2.0
# 28 Days Later (2002)                                 0.0   0.0   4.0   0.0
# 40-Year-Old Virgin, The (2005)                       0.0   0.0   4.0   0.0
# A.I. Artificial Intelligence (2001)                  3.0   0.0   1.0   0.0
# ...                                                  ...   ...   ...   ...
# X-Men (2000)                                         4.0   0.0   4.0   0.0
# X2: X-Men United (2003)                              3.0   0.0   4.0   0.0
# You've Got Mail (1998)                               2.0   0.0   0.0   0.0
# Young Frankenstein (1974)                            3.0   3.0   0.0   3.0
# Zoolander (2001)                                     0.0   0.0   1.0   0.0
#
# userId                                              156   208   ...  2242  \
# title                                                           ...
# 101 Dalmatians (One Hundred and One Dalmatians)...   5.0   0.0  ...   0.0
# 2001: A Space Odyssey (1968)                         0.0   4.0  ...   0.0
# 28 Days Later (2002)                                 0.0   4.0  ...   0.0
# 40-Year-Old Virgin, The (2005)                       0.0   3.0  ...   0.0
# A.I. Artificial Intelligence (2001)                  0.0   3.0  ...   0.0
# ...                                                  ...   ...  ...   ...
# X-Men (2000)                                         4.0   0.0  ...   0.0
# X2: X-Men United (2003)                              0.0   0.0  ...   0.0
# You've Got Mail (1998)                               0.0   1.0  ...   3.0
# Young Frankenstein (1974)                            5.0   4.0  ...   4.0
# Zoolander (2001)                                     0.0   0.0  ...   3.0
#
# userId                                              2259  2261  2269  2270  \
# title
# 101 Dalmatians (One Hundred and One Dalmatians)...   4.0   3.0   0.0   0.0
# 2001: A Space Odyssey (1968)                         1.0   5.0   4.0   5.0
# 28 Days Later (2002)                                 0.0   1.0   0.0   0.0
# 40-Year-Old Virgin, The (2005)                       0.0   0.0   3.0   3.0
# A.I. Artificial Intelligence (2001)                  0.0   4.0   0.0   3.0
# ...                                                  ...   ...   ...   ...
# X-Men (2000)                                         0.0   3.0   0.0   4.0
# X2: X-Men United (2003)                              0.0   3.0   0.0   3.0
# You've Got Mail (1998)                               3.0   2.0   0.0   2.0
# Young Frankenstein (1974)                            0.0   4.0   3.0   0.0
# Zoolander (2001)                                     0.0   1.0   0.0   0.0
#
# userId                                              2311  2344  2349  2352  \
# title
# 101 Dalmatians (One Hundred and One Dalmatians)...   5.0   0.0   4.0   0.0
# 2001: A Space Odyssey (1968)                         5.0   5.0   2.0   1.0
# 28 Days Later (2002)                                 0.0   4.0   0.0   0.0
# 40-Year-Old Virgin, The (2005)                       0.0   0.0   3.0   0.0
# A.I. Artificial Intelligence (2001)                  0.0   4.0   4.0   0.0
# ...                                                  ...   ...   ...   ...
# X-Men (2000)                                         0.0   3.0   4.0   2.0
# X2: X-Men United (2003)                              0.0   3.0   4.0   0.0
# You've Got Mail (1998)                               0.0   0.0   0.0   0.0
# Young Frankenstein (1974)                            3.0   0.0   3.0   1.0
# Zoolander (2001)                                     0.0   0.0   5.0   2.0
#
# userId                                              2367
# title
# 101 Dalmatians (One Hundred and One Dalmatians)...   0.0
# 2001: A Space Odyssey (1968)                         3.0
# 28 Days Later (2002)                                 4.0
# 40-Year-Old Virgin, The (2005)                       4.0
# A.I. Artificial Intelligence (2001)                  3.0
# ...                                                  ...
# X-Men (2000)                                         4.0
# X2: X-Men United (2003)                              4.0
# You've Got Mail (1998)                               2.0
# Young Frankenstein (1974)                            0.0
# Zoolander (2001)                                     3.0
#
# [526 rows x 140 columns]

# %%
from scipy.sparse import csr_matrix
movie_sparse=csr_matrix(movie_pivot)

# %%
from sklearn.neighbors import NearestNeighbors
model=NearestNeighbors( n_neighbors=7,algorithm='brute',metric='cosine')

# %%
model.fit(movie_sparse)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=7)

# %%
df.drop(columns=['genres','userId','rating'],inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv('codf.csv',index=False)

# %%
distances,suggestions=model.kneighbors(movie_pivot.iloc[524,:].values.reshape(1,-1))

# %%
distances
# Out:
# array([[6.66133815e-16, 2.60243234e-01, 2.70102526e-01, 2.77348770e-01,
#         2.81478066e-01, 2.84966948e-01, 2.89683692e-01]])

# %%
suggestions
# Out:
# array([[524, 518, 382,  13, 378,  73, 328]])

# %%
df1=df.copy()
ti=[]
for i in df1['title']:
    ti.append(i.split(' (')[0])
df1['title']=ti

# %%
for i in range(len(suggestions)):
    print(movie_pivot.index[suggestions[i]])
# Out:
# Index(['Young Frankenstein (1974)', 'Wizard of Oz, The (1939)',
#        'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)',
#        'Airplane! (1980)', 'Psycho (1960)', 'Blazing Saddles (1974)',
#        'Monty Python and the Holy Grail (1975)'],
#       dtype='object', name='title')

# %%
def reco(movie_name):
    movie_id=df1[df1['title']=='Toy Story'].drop_duplicates('title')['movieId'].values[0]
    distances,suggestions=model.kneighbors(movie_pivot.iloc[movie_id,:].values.reshape(1,-1))



    for i in range(len(suggestions)):
        return (movie_pivot.index[suggestions[i]])

# %%
res=reco("It Conquered the World")

# %%
for i in res:
    print(i)
# Out:
# 2001: A Space Odyssey (1968)
# Blade Runner (1982)
# Clockwork Orange, A (1971)
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)
# Fargo (1996)
# Silence of the Lambs, The (1991)
# Godfather, The (1972)
